# %%
#Creating a Basic hardcoded ChatBot using Python-NLTK
# !pip install nltk

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.chat.util import Chat, reflections

def create_pairs():
    return [
        (r"my name is (.*)", 
         ["Hello %1, nice to meet you!", "Hey %1! How can I help you?"]),

        (r"(hi|hello|hey|hola)", 
         ["Hello!", "Hi there!", "Hey!"]),

        (r"what is your name\??", 
         ["I'm Geeky, your chatbot assistant."]),

        (r"how are you\??", 
         ["I'm doing great!", "All good here! What about you?"]),

        (r"(.*) (created|made) you\??", 
         ["I was created using Python and NLTK."]),

        (r"(.*) help (.*)", 
         ["I can answer basic questions. Try asking something else!"]),

        (r"(.*) (college|university|study)(.*)", 
         ["That sounds interesting! Tell me more about it."]),

        (r"(.*) (weather|temperature)(.*)", 
         ["I can't check live weather yet, but it's always a good idea to carry an umbrella!"]),

        (r"(bye|quit|exit)", 
         ["Goodbye! Take care.", "See you soon!"]),

        (r"(.*)", 
         ["Hmm... I didn't quite get that.", 
          "Can you rephrase that?", 
          "Interesting... tell me more!"])
    ]

def start_chat():
    print("\n🤖 Geeky ChatBot")
    print("Type 'bye', 'quit', or 'exit' to end the chat.\n")

    chatbot = Chat(create_pairs(), reflections)
    chatbot.converse()

if __name__ == "__main__":
    start_chat()
# Out:
# 🤖 Geeky ChatBot
# Type 'bye', 'quit', or 'exit' to end the chat.
# > my name is AMit
# Hey amit! How can I help you?
# > By studying
# That sounds interesting! Tell me more about it.
# > I study Btech
# That sounds interesting! Tell me more about it.
# > I can't check live weather yet, but it's always a good idea to carry an umbrella
# I can't check live weather yet, but it's always a good idea to carry an umbrella!
# > bye
# Goodbye! Take care.
# > exit
# Goodbye! Take care.
# > Who Created you
# I was created using Python and NLTK.
# > Help
# Hmm... I didn't quite get that.
# > nice
# Interesting... tell me more!
# > I love girls
# Interesting... tell me more!
# > exit
# Goodbye! Take care.
# > fuck
# Can you rephrase that?
# > Exit chat
# See you soon!
# > c-!
# Interesting... tell me more!
# > QUIT
# Goodbye! Take care.
# > V.JV.
# Interesting... tell me more!
# > BJLLK
# Can you rephrase that?
# > BK;K
# Interesting... tell me more!
# >
# ...

# %%
import nltk
nltk.download('punkt')
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pip install speechrecognition pyttsx3 pyaudio
# Out:
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#     --------------------------------------- 0.8/32.9 MB 7.2 MB/s eta 0:00:05
#    - -------------------------------------- 1.3/32.9 MB 6.8 MB/s eta 0:00:05
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\KIIT\miniconda3\Lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\KIIT\miniconda3\Lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ~~~~~~~~~~~~~^^^^^
#   File "C:\Users\KIIT\miniconda3\Lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ~~~~~~~~~~~~~^^^^^
# ...

# %%
from nltk.chat.util import Chat, reflections

def create_pairs():
    return [
        (r"my name is (.*)", 
         ["Hello %1, nice to meet you!", "Hey %1! How can I help you?"]),

        (r"(hi|hello|hey|hola)", 
         ["Hello!", "Hi there!", "Hey!"]),

        (r"what is your name\??", 
         ["I'm Geeky, your chatbot assistant."]),

        (r"how are you\??", 
         ["I'm doing great!", "All good here! What about you?"]),

        (r"(.*) (created|made) you\??", 
         ["I was created using Python and NLTK."]),

        (r"(.*) help (.*)", 
         ["I can answer basic questions. Try asking something else!"]),

        (r"(.*) (college|university|study)(.*)", 
         ["That sounds interesting! Tell me more about it."]),

        (r"(.*) (weather|temperature)(.*)", 
         ["I can't check live weather yet, but it's always a good idea to carry an umbrella!"]),

        (r"(bye|quit|exit)", 
         ["Goodbye! Take care.", "See you soon!"]),

        (r"(.*)", 
         ["Hmm... I didn't quite get that.", 
          "Can you rephrase that?", 
          "Interesting... tell me more!"])
    ]

def start_chat():
    print("\n🤖 Geeky ChatBot")
    print("Type 'bye', 'quit', or 'exit' to end the chat.\n")

    chatbot = Chat(create_pairs(), reflections)
    chatbot.converse()

if __name__ == "__main__":
    start_chat()
# Out:
# 🤖 Geeky ChatBot
# Type 'bye', 'quit', or 'exit' to end the chat.
# > BYE
# Goodbye! Take care.
# > BYE
# Goodbye! Take care.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 46
#      43     chatbot.converse()
#      45 if __name__ == "__main__":
# ---> 46     start_chat()
#
# Cell In[8], line 43, in start_chat()
#      40 print("Type 'bye', 'quit', or 'exit' to end the chat.\n")
#      42 chatbot = Chat(create_pairs(), reflections)
# ---> 43 chatbot.converse()
#
# File ~\miniconda3\Lib\site-packages\nltk\chat\util.py:118, in Chat.converse(self, quit)
#     116 user_input = quit
#     117 try:
# --> 118     user_input = input(">")
#     119 except EOFError:
#     120     print(user_input)
#
# File ~\miniconda3\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
# ...

# %%
pip cache purge
# Out:
# Files removed: 2361 (1598.3 MB)
# Directories removed: 65
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install speechrecognition pyttsx3 pyaudio
# Out:
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    - -------------------------------------- 1.0/32.9 MB 7.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.4/32.9 MB 10.7 MB/s eta 0:00:03
#    ------ --------------------------------- 5.2/32.9 MB 11.1 MB/s eta 0:00:03
#    ------- -------------------------------- 6.0/32.9 MB 9.5 MB/s eta 0:00:03
#    ------- -------------------------------- 6.6/32.9 MB 7.3 MB/s eta 0:00:04
#    -------- ------------------------------- 6.8/32.9 MB 6.5 MB/s eta 0:00:04
#    -------- ------------------------------- 7.1/32.9 MB 5.6 MB/s eta 0:00:05
#    -------- ------------------------------- 7.3/32.9 MB 5.0 MB/s eta 0:00:06
#    --------- ------------------------------ 7.6/32.9 MB 4.5 MB/s eta 0:00:06
#    --------- ------------------------------ 8.1/32.9 MB 4.0 MB/s eta 0:00:07
#    --------- ------------------------------ 8.1/32.9 MB 4.0 MB/s eta 0:00:07
# ...

# %%
{
  "intents": [
    {
      "tag": "greeting",
      "patterns": ["hi", "hello", "hey", "hola"],
      "responses": ["Hello!", "Hi there!", "Hey! How can I help you?"]
    },
    {
      "tag": "goodbye",
      "patterns": ["bye", "exit", "quit"],
      "responses": ["Goodbye!", "See you soon!", "Take care!"]
    },
    {
      "tag": "name",
      "patterns": ["what is your name", "who are you"],
      "responses": ["I am your chatbot assistant built with Python."]
    },
    {
      "tag": "help",
      "patterns": ["help", "can you help me"],
      "responses": ["Sure! Ask me anything simple."]
    }
  ]
}
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['hi', 'hello', 'hey', 'hola'],
#    'responses': ['Hello!', 'Hi there!', 'Hey! How can I help you?']},
#   {'tag': 'goodbye',
#    'patterns': ['bye', 'exit', 'quit'],
#    'responses': ['Goodbye!', 'See you soon!', 'Take care!']},
#   {'tag': 'name',
#    'patterns': ['what is your name', 'who are you'],
#    'responses': ['I am your chatbot assistant built with Python.']},
#   {'tag': 'help',
#    'patterns': ['help', 'can you help me'],
#    'responses': ['Sure! Ask me anything simple.']}]}

# %%
import json

data = {
  "intents": [
    {
      "tag": "greeting",
      "patterns": ["hi", "hello", "hey"],
      "responses": ["Hello!", "Hi there!", "Hey!"]
    },
    {
      "tag": "goodbye",
      "patterns": ["bye", "exit", "quit"],
      "responses": ["Goodbye!", "See you soon!", "Take care!"]
    },
    {
      "tag": "name",
      "patterns": ["what is your name", "who are you"],
      "responses": ["I am your chatbot assistant."]
    }
  ]
}

with open("intents.json", "w") as file:
    json.dump(data, file)

print("intents.json created successfully!")
# Out:
# intents.json created successfully!

# %%
import json

with open("intents.json", "r") as file:
    intents = json.load(file)

print("Loaded successfully!")
# Out:
# Loaded successfully!

# %%
intents
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['hi', 'hello', 'hey'],
#    'responses': ['Hello!', 'Hi there!', 'Hey!']},
#   {'tag': 'goodbye',
#    'patterns': ['bye', 'exit', 'quit'],
#    'responses': ['Goodbye!', 'See you soon!', 'Take care!']},
#   {'tag': 'name',
#    'patterns': ['what is your name', 'who are you'],
#    'responses': ['I am your chatbot assistant.']}]}

# %%
import random
import re

# Your intents data
intents = {
    "intents": [
        {
            "tag": "greeting",
            "patterns": ["hi", "how are you", "hello", "hey", "hai"],
            "responses": ["Hi, how are you?", "Hey! How are you?", "Hello!"]
        },
        {
            "tag": "goodbye",
            "patterns": ["bye", "see you later", "good bye"],
            "responses": ["Bye!", "See you later!", "Take care!"]
        },
        {
            "tag": "thanks",
            "patterns": ["thankyou", "thanks", "thats helpful"],
            "responses": ["You're welcome!", "My pleasure!", "Glad I could help!"]
        },
        {
            "tag": "positive_health",
            "patterns": ["feeling great", "better", "good", "fine"],
            "responses": ["That's great to hear!", "Stay positive!"]
        },
        {
            "tag": "negative_health",
            "patterns": ["feeling bad", "uncomfortable", "dizzy", "tired"],
            "responses": ["Don't worry, you'll be fine.", "I'm here with you."]
        },
        {
            "tag": "bored",
            "patterns": ["im bored", "bored"],
            "responses": ["Want a joke or riddle?", "Let's do something fun!"]
        },
        {
            "tag": "jokes",
            "patterns": ["tell me joke", "joke", "funny"],
            "responses": [
                "Why don’t scientists trust atoms? Because they make up everything!",
                "Why was the math book sad? It had too many problems."
            ]
        },
        {
            "tag": "riddle",
            "patterns": ["tell me riddle", "riddle"],
            "responses": [
                "What has keys but can't open locks? A piano.",
                "What goes up but never comes down? Your age."
            ]
        }
    ]
}

# Function to clean input
def clean_text(text):
    return re.sub(r'[^a-zA-Z ]', '', text.lower())

# Match user input with patterns
def get_response(user_input):
    user_input = clean_text(user_input)

    for intent in intents["intents"]:
        for pattern in intent["patterns"]:
            if pattern in user_input:
                return random.choice(intent["responses"])

    return "Sorry, I didn't understand that."

# Chat loop
print("🤖 ChatBot: Type 'quit' to exit\n")

while True:
    user = input("You: ")

    if user.lower() == "quit":
        print("Bot: Goodbye!")
        break

    response = get_response(user)
    print("Bot:", response)
# Out:
# 🤖 ChatBot: Type 'quit' to exit
# You:  HI
# Bot: Hello!
# You:  HI
# Bot: Hey! How are you?
# You:  N8CE
# Bot: Sorry, I didn't understand that.
# You:  NICE
# Bot: Sorry, I didn't understand that.
# You:  tell me a joke
# Bot: Why was the math book sad? It had too many problems.
# You:  i am sad
# Bot: Sorry, I didn't understand that.
# You:  nice
# Bot: Sorry, I didn't understand that.
# You:  hi
# Bot: Hey! How are you?
# You:  what should i eat
# Bot: Sorry, I didn't understand that.
# You:  tell me a joke
# Bot: Why don’t scientists trust atoms? Because they make up everything!
# You:   motivate me
# Bot: Sorry, I didn't understand that.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 75
#      72 print("🤖 ChatBot: Type 'quit' to exit\n")
#      74 while True:
# ---> 75     user = input("You: ")
#      77     if user.lower() == "quit":
# ...

# %%
intents
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['hi', 'how are you', 'hello', 'hey', 'hai'],
#    'responses': ['Hi, how are you?', 'Hey! How are you?', 'Hello!']},
#   {'tag': 'goodbye',
#    'patterns': ['bye', 'see you later', 'good bye'],
#    'responses': ['Bye!', 'See you later!', 'Take care!']},
#   {'tag': 'thanks',
#    'patterns': ['thankyou', 'thanks', 'thats helpful'],
#    'responses': ["You're welcome!", 'My pleasure!', 'Glad I could help!']},
#   {'tag': 'positive_health',
#    'patterns': ['feeling great', 'better', 'good', 'fine'],
#    'responses': ["That's great to hear!", 'Stay positive!']},
#   {'tag': 'negative_health',
#    'patterns': ['feeling bad', 'uncomfortable', 'dizzy', 'tired'],
#    'responses': ["Don't worry, you'll be fine.", "I'm here with you."]},
#   {'tag': 'bored',
#    'patterns': ['im bored', 'bored'],
#    'responses': ['Want a joke or riddle?', "Let's do something fun!"]},
#   {'tag': 'jokes',
# ...

# %%
import nltk
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

words = []
classes = []
documents = []

ignore = ['?', '!', '.', ',']

for intent in intents['intents']:
    for pattern in intent['patterns']:

        # SAFE TOKENIZATION (NO punkt needed)
        w = tokenizer.tokenize(pattern.lower())

        words.extend([word for word in w if word not in ignore])

        documents.append((w, intent['tag']))

        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# clean data
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

print("Total words:", len(words))
print("Classes:", classes)
# Out:
# Total words: 30
# Classes: ['bored', 'goodbye', 'greeting', 'jokes', 'negative_health', 'positive_health', 'riddle', 'thanks']

# %%
# Perform stemming and lower each word as well as remove duplicates
words = [stemmer.stem(w.lower()) for w in words if w not in ignore]
words = sorted(list(set(words)))

# remove duplicate classes
classes = sorted(list(set(classes)))

print (len(documents), "documents")
print (len(classes), "classes", classes)
print (len(words), "unique stemmed words", words)
# Out:
# 26 documents
# 8 classes ['bored', 'goodbye', 'greeting', 'jokes', 'negative_health', 'positive_health', 'riddle', 'thanks']
# 30 unique stemmed words ['ar', 'bad', 'bet', 'bor', 'bye', 'dizzy', 'feel', 'fin', 'funny', 'good', 'gre', 'hai', 'hello', 'help', 'hey', 'hi', 'how', 'im', 'jok', 'lat', 'me', 'riddl', 'see', 'tel', 'thank', 'thankyou', 'that', 'tir', 'uncomfort', 'you']

# %%
import numpy as np
import random
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

training = []
output_empty = [0] * len(classes)

# -----------------------------
# Build training data
# -----------------------------
for doc in documents:

    bag = []
    pattern_words = doc[0]

    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]

    for w in words:
        bag.append(1 if w in pattern_words else 0)

    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# -----------------------------
# IMPORTANT FIX
# -----------------------------
random.shuffle(training)

training = np.array(training, dtype=object)

train_x = np.array([item[0] for item in training])
train_y = np.array([item[1] for item in training])

print("Training data ready!")
print("X shape:", train_x.shape)
print("Y shape:", train_y.shape)
# Out:
# Training data ready!
# X shape: (26, 30)
# Y shape: (26, 8)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
import numpy as np
import random

# Convert data to numpy
train_x = np.array(train_x)
train_y = np.array(train_y)

# -----------------------------
# Build Neural Network
# -----------------------------
model = Sequential()

model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(len(train_y[0]), activation='softmax'))

# -----------------------------
# Compile Model
# -----------------------------
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# -----------------------------
# Train Model
# -----------------------------
model.fit(
    train_x,
    train_y,
    epochs=200,
    batch_size=8,
    verbose=1
)

# -----------------------------
# Save Model
# -----------------------------
model.save("chatbot_model.h5")

print("Model trained and saved successfully!")
# Out:
# C:\Users\KIIT\miniconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.1923 - loss: 2.0955
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2308 - loss: 2.0696
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1154 - loss: 2.0809
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1538 - loss: 2.0324
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2308 - loss: 2.0511
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2692 - loss: 2.0376
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1538 - loss: 2.0325
# Epoch 8/200
# ...

# %%
import pickle

data = {
    'words': words,
    'classes': classes,
    'train_x': train_x,
    'train_y': train_y
}

with open("training_data.pkl", "wb") as file:
    pickle.dump(data, file)

print("Training data saved successfully!")
# Out:
# Training data saved successfully!

# %%
import pickle

with open("training_data.pkl", "rb") as file:
    data = pickle.load(file)

words = data['words']
classes = data['classes']
train_x = data['train_x']
train_y = data['train_y']

print("Data loaded successfully!"
# Out:
# Data loaded successfully!

# %%
import pickle

with open("training_data.pkl", "rb") as file:
    data = pickle.load(file)

words = data['words']
classes = data['classes']
train_x = data['train_x']
train_y = data['train_y']

print("Data loaded successfully!")
# Out:
# Data loaded successfully!

# %%
import pickle

with open("training_data.pkl", "rb") as file:
    data = pickle.load(file)

words = data['words']
classes = data['classes']
train_x = data['train_x']
train_y = data['train_y']

print("Data loaded successfully!")
# Out:
# Data loaded successfully!

# %%
import numpy as np
import random
import json
import nltk
import tensorflow as tf
from nltk.stem import PorterStemmer
from nltk.tokenize import TreebankWordTokenizer
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
import json

data = {
  "intents": [
    {
      "tag": "greeting",
      "patterns": ["hi", "hello", "hey"],
      "responses": ["Hello!", "Hi there!", "Hey!"]
    },
    {
      "tag": "goodbye",
      "patterns": ["bye", "exit", "quit"],
      "responses": ["Goodbye!", "See you soon!", "Take care!"]
    },
    {
      "tag": "name",
      "patterns": ["what is your name", "who are you"],
      "responses": ["I am GeekyBot 🤖"]
    }
  ]
}
stemmer = PorterStemmer()
tokenizer = TreebankWordTokenizer()

words = []
classes = []
documents = []

ignore = ['?', '!', '.', ',']

for intent in data['intents']:
    for pattern in intent['patterns']:

        w = tokenizer.tokenize(pattern.lower())

        words.extend([stemmer.stem(word) for word in w if word not in ignore])

        documents.append((w, intent['tag']))

        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

print("Words:", len(words))
print("Classes:", classes)
training = []
output_empty = [0] * len(classes)

for doc in documents:

    bag = []
    pattern_words = [stemmer.stem(word.lower()) for word in doc[0]]

    for w in words:
        bag.append(1 if w in pattern_words else 0)

    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

random.shuffle(training)

training = np.array(training, dtype=object)

train_x = np.array([i[0] for i in training])
train_y = np.array([i[1] for i in training])
model = Sequential()

model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(len(train_y[0]), activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.fit(train_x, train_y, epochs=200, batch_size=8, verbose=1)
model.save("chatbot_model.h5")

import pickle

with open("training_data.pkl", "wb") as file:
    pickle.dump({
        "words": words,
        "classes": classes,
        "train_x": train_x,
        "train_y": train_y
    }, file)

print("Model and data saved!")
# Out:
# Words: 13
# Classes: ['goodbye', 'greeting', 'name']
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0000e+00 - loss: 1.1963
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3750 - loss: 1.0826
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3750 - loss: 1.0389
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6250 - loss: 1.0795
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.2500 - loss: 1.1065
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2500 - loss: 1.0905
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 1.0268
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3750 - loss: 1.1821
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7500 - loss: 0.9813
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1250 - loss: 1.0822
# Epoch 11/200
# ...

# %%
from tensorflow.keras.models import load_model

model = load_model("chatbot_model.h5")

print("Model loaded successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!

# %%
def clean_up_sentence(sentence):
    # tokenizing the pattern
    sentence_words = nltk.word_tokenize(sentence)
    # stemming each word
    sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    return sentence_words

# returning bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=False):
    # tokenizing the pattern
    sentence_words = clean_up_sentence(sentence)
    # generating bag of words
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)

    return(np.array(bag))

# %%
ERROR_THRESHOLD = 0.30
def classify(sentence):
    # generate probabilities from the model
    results = model.predict([bow(sentence, words)])[0]
    # filter out predictions below a threshold
    results = [[i,r] for i,r in enumerate(results) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append((classes[r[0]], r[1]))
    # return tuple of intent and probability
    return return_list

def response(sentence, userID='123', show_details=False):
    results = classify(sentence)
    # if we have a classification then find the matching intent tag
    if results:
        # loop as long as there are matches to process
        while results:
            for i in intents['intents']:
                # find a tag matching the first result
                if i['tag'] == results[0][0]:
                    # a random response from the intent
                    return random.choice(i['responses'])

            results.pop(0)

# %%
import random
import tkinter
from tkinter import *
def rock_paper_scissor():
    #Creating GUI with tkinter
   
    def play():
        user_choice = EntryBox.get("1.0",'end-1c').strip()
        EntryBox.delete("0.0",END)
        if user_choice != '':
            ChatLog.config(state=NORMAL)
            ChatLog.insert(END, "You: " +user_choice + '\n\n')
            ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
            select = ['rock','paper','scissor']
            bot_choice = random.choice(select)
            ChatLog.insert(END, "Bot: " +bot_choice + '\n\n')
            if(user_choice.lower()=='rock' and bot_choice.lower()=='rock'):
                ChatLog.insert(END, "MATCH DRAWS \n \n")
                ChatLog.insert(END, "-------------------------------------- \n \n")
            if(user_choice.lower()=='rock' and bot_choice.lower()=='paper'):
                ChatLog.insert(END, "BOT WINS \n \n")
                ChatLog.insert(END, "-------------------------------------- \n \n")
            if(user_choice.lower()=='rock' and bot_choice.lower()=='scissor'):
                ChatLog.insert(END, "YOU WINS \n \n")
                ChatLog.insert(END, "-------------------------------------- \n \n")
            if(user_choice.lower()=='paper' and bot_choice.lower()=='rock'):
                ChatLog.insert(END, "YOU WINS \n \n")
                ChatLog.insert(END, "-------------------------------------- \n \n")
            if(user_choice.lower()=='paper' and bot_choice.lower()=='paper'):
                ChatLog.insert(END, "MATCH DRAWS \n \n")
                ChatLog.insert(END, "-------------------------------------- \n \n")
            if(user_choice.lower()=='paper' and bot_choice.lower()=='scissor'):
                ChatLog.insert(END, "BOT WINS \n \n")
                ChatLog.insert(END, "-------------------------------------- \n \n")
            if(user_choice.lower()=='scissor' and bot_choice.lower()=='rock'):
                ChatLog.insert(END, "BOT WINS \n \n")
                ChatLog.insert(END, "-------------------------------------- \n \n")
            if(user_choice.lower()=='scissor' and bot_choice.lower()=='paper'):
                ChatLog.insert(END, "YOU WINS \n \n")
                ChatLog.insert(END, "-------------------------------------- \n \n")    
            if(user_choice.lower()=='scissor' and bot_choice.lower()=='scissor'):
                ChatLog.insert(END, "MATCH DRAWS \n \n")
                ChatLog.insert(END, "-------------------------------------- \n \n")
            ChatLog.insert(END, "BOT: choose any one \n 1.ROCK \n 2. PAPER \n 3.SCISSOR \n ")
            ChatLog.config(state=DISABLED)
            ChatLog.yview(END)



    base = Tk()
    base.title("GAME")
    base.geometry("400x500")
    base.resizable(width=FALSE, height=FALSE)

    #Create Chat window
    ChatLog = Text(base, bd=0, bg="#FFCCCC", height="8", width="50", font="Arial",)
    ChatLog.insert(END, "BOT: choose any one \n 1.ROCK \n 2. PAPER \n 3.SCISSOR \n "  )
    ChatLog.config(state=DISABLED)
    #Bind scrollbar to Chat window
    scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
    ChatLog['yscrollcommand'] = scrollbar.set
    #Create Button to send message
    SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= play)
    #Create the box to enter message
    EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
    #EntryBox.bind("<Return>", send)
    #Place all components on the screen
    scrollbar.place(x=376,y=6, height=386)
    ChatLog.place(x=6,y=6, height=386, width=370)
    EntryBox.place(x=128, y=401, height=90, width=265)
    SendButton.place(x=6, y=401, height=90)
    base.mainloop()

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
        res = response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
base = Tk()
base.title("CHATBOT")
base.geometry("400x500")

base.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatLog = Text(base, bd=0, bg="#CCFFFF", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
#Create Button to send message
sendButton = Button(base, font=("Verdana",12,'bold'), text="send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )
playButton = Button(base, font=("Verdana",12,'bold'), text="PLAY", width="6", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= rock_paper_scissor )
#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
sendButton.place(x=6, y=401, height=90)
playButton.place(x=300,y=10, height=40)
base.mainloop()

# %%
#sentimental analysis
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import names

def word_feats(words):
    return dict([(word, True) for word in words])
 
positive_vocab = [ 'awesome', 'outstanding', 'fantastic', 'terrific', 'good', 'nice', 'great', ':)' ]
negative_vocab = [ 'bad', 'terrible','useless', 'hate', ':(','not' ]


positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]


train_set = negative_features + positive_features 

classifier = NaiveBayesClassifier.train(train_set) 

# Predict
neg = 0
pos = 0
sentence = input()
sentence = sentence.lower()
words = sentence.split(' ')
for word in words:
    classResult = classifier.classify( word_feats(word))
    if classResult == 'neg':
        neg = neg + 1
    if classResult == 'pos':
        pos = pos + 1

print('Positive: ' + str(float(pos)/len(words)))
print('Negative: ' + str(float(neg)/len(words)))
# Out:
#  fuck
# Positive: 1.0
# Negative: 0.0
